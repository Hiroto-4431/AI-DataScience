# %% [markdown]
# <a href="https://colab.research.google.com/github/Hiroto-4431/AI-DataScience/blob/main/module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 概要
# - Numpy
# - Pandas
# - Matplotlib

# %% [markdown]
# ## Numpy

# %%
import numpy as np

# %%
# ベクトル np.array()関数
a = np.array([1, 2, 3])

# %%
a # ndarrayオブジェクト ← クラス
# Out:
# array([1, 2, 3])

# %%
# shape属性 : ベクトル、行列の形
a.shape
# Out:
# (3,)

# %%
# ndim属性 : 次元数
a.ndim
# Out:
# 1

# %% [markdown]
# ## Pandas

# %%
# インポート
import pandas as pd

# %%
# csvファイルを読み込む
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
# データ型
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# df.head()メソッド
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
# 最後の要素だけ取得
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
# longitudeのみを取得
df['longitude'].head()
# Out:
# 0   -114.31
# 1   -114.47
# 2   -114.56
# 3   -114.57
# 4   -114.57
# Name: longitude, dtype: float64

# %% [markdown]
# ## Matplotlib

# %%
# インポート
import matplotlib.pyplot as plt

# %%
# データの読み込み
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %% [markdown]
# ### 散布図

# %%
plt.scatter(x=df['median_income'], y=df['median_house_value']);

# %% [markdown]
# ### ヒストグラム

# %%
plt.hist(x=df['median_house_value']);

# %%
# ビンの数を変更
plt.hist(x=df['median_house_value'], bins=50);
